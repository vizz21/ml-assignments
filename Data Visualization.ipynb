# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:/Users/User/Desktop/ml Assi/diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25904/2255720674.py in <module>
# ----> 1 df.count()
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    9716                 # the or any_extension_types is really only hit for single-
#    9717                 # column frames with an extension array
# -> 9718                 result = notna(frame).sum(axis=axis)
#    9719             else:
#    9720                 # GH13407
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10426                 numeric_only=numeric_only,
#   10427             )
# > 10428         return self._reduce(
#   10429             func,
#   10430             name=name,
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    9849             # After possibly _get_data and transposing, we are now in the
#    9850             #  simple case where we can use BlockManager.reduce
# -> 9851             res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#    9852             out = df._constructor(res).iloc[0]
#    9853             if out_dtype is not None:
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in reduce(self, func, ignore_failures)
#    1288             if res_blocks:
#    1289                 indexer = np.concatenate([blk.mgr_locs.as_array for blk in res_blocks])
# -> 1290                 new_mgr = self._combine(res_blocks, copy=False, index=index)
#    1291             else:
#    1292                 indexer = []
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in _combine(self, blocks, copy, index)
#     552
#     553         # FIXME: optimization potential
# --> 554         indexer = np.sort(np.concatenate([b.mgr_locs.as_array for b in blocks]))
#     555         inv_indexer = lib.get_reverse_indexer(indexer, self.shape[0])
#     556
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25904/1134722465.py in <module>
# ----> 1 df.corr()
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods)
#    9371         cats   0.3   1.0
#    9372         """
# -> 9373         numeric_df = self._get_numeric_data()
#    9374         cols = numeric_df.columns
#    9375         idx = cols.copy()
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in _get_numeric_data(self)
#    5610     @final
#    5611     def _get_numeric_data(self):
# -> 5612         return self._constructor(self._mgr.get_numeric_data()).__finalize__(self)
#    5613
#    5614     @final
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in get_numeric_data(self, copy)
#     535             Whether to copy the blocks
#     536         """
# --> 537         return self._combine([b for b in self.blocks if b.is_numeric], copy)
#     538
#     539     def _combine(
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in _combine(self, blocks, copy, index)
#     552
#     553         # FIXME: optimization potential
# --> 554         indexer = np.sort(np.concatenate([b.mgr_locs.as_array for b in blocks]))
#     555         inv_indexer = lib.get_reverse_indexer(indexer, self.shape[0])
#     556
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df.Age[:10]
# Out:
# 0    50
# 1    31
# 2    32
# 3    21
# 4    33
# 5    30
# 6    26
# 7    29
# 8    53
# 9    54
# Name: Age, dtype: int64

# %%
df.iloc[1]
# Out:
# Pregnancies                  1.000
# Glucose                     85.000
# BloodPressure               66.000
# SkinThickness               29.000
# Insulin                      0.000
# BMI                         26.600
# DiabetesPedigreeFunction     0.351
# Age                         31.000
# Outcome                      0.000
# Name: 1, dtype: float64

# %%
df.sort_values('Age')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 255            1      113             64             35        0  33.6
# 60             2       84              0              0        0   0.0
# 102            0      125             96              0        0  22.5
# 182            1        0             74             20       23  27.7
# 623            0       94             70             27      115  43.5
# ..           ...      ...            ...            ...      ...   ...
# 123            5      132             80              0        0  26.8
# 684            5      136             82              0        0   0.0
# 666            4      145             82             18        0  32.5
# 453            2      119              0              0        0  19.6
# 459            9      134             74             33       60  25.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 255                     0.543   21        1
# 60                      0.304   21        0
# 102                     0.262   21        0
# 182                     0.299   21        0
# 623                     0.347   21        0
# ..                        ...  ...      ...
# 123                     0.186   69        0
# 684                     0.640   69        0
# 666                     0.235   70        1
# 453                     0.832   72        0
# 459                     0.460   81        0
#
# [768 rows x 9 columns]

# %%
#np.sort(df.Age.unique())

# %%
import matplotlib.pyplot as plt

# %%
cols =df.columns
print(cols)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]>

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25904/2850629520.py in <module>
# ----> 1 df.isna().sum()
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10426                 numeric_only=numeric_only,
#   10427             )
# > 10428         return self._reduce(
#   10429             func,
#   10430             name=name,
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    9849             # After possibly _get_data and transposing, we are now in the
#    9850             #  simple case where we can use BlockManager.reduce
# -> 9851             res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#    9852             out = df._constructor(res).iloc[0]
#    9853             if out_dtype is not None:
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in reduce(self, func, ignore_failures)
#    1288             if res_blocks:
#    1289                 indexer = np.concatenate([blk.mgr_locs.as_array for blk in res_blocks])
# -> 1290                 new_mgr = self._combine(res_blocks, copy=False, index=index)
#    1291             else:
#    1292                 indexer = []
#
# ~\anaconda3\envs\mlcl\lib\site-packages\pandas\core\internals\managers.py in _combine(self, blocks, copy, index)
#     552
#     553         # FIXME: optimization potential
# --> 554         indexer = np.sort(np.concatenate([b.mgr_locs.as_array for b in blocks]))
#     555         inv_indexer = lib.get_reverse_indexer(indexer, self.shape[0])
#     556
#
# TypeError: 'numpy.ndarray' object is not callable
